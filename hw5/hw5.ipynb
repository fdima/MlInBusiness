# %%
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd 
import seaborn as sns

from sklearn.metrics import mean_squared_error

import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA

# %% [markdown]
#  1. Прочитайте базу my_BRENT2019.csv

# %%
path_brent = 'my_BRENT2019.csv'
brent_data = pd.read_csv(path_brent,sep = ',', index_col=[0], parse_dates=[0])
brent_data.head()
# Out:
#             Значение  year  month  dayofmonth  quarter  dayofyear  weekofyear  \
# Дата
# 2010-09-01     76.37  2010      9           1        3        244          35
# 2010-09-02     76.89  2010      9           2        3        245          35
# 2010-09-03     76.57  2010      9           3        3        246          35
# 2010-09-04     76.62  2010      9           4        3        247          35
# 2010-09-05     76.63  2010      9           5        3        248          35
#
#             dayofweek  is_holiday  is_prev_holiday  is_next_holiday
# Дата
# 2010-09-01          2           0                0                0
# 2010-09-02          3           0                0                0
# 2010-09-03          4           0                0                0
# 2010-09-04          5           0                0                0
# 2010-09-05          6           0                1                0

# %% [markdown]
#  2. Добавьте первые разности и стоимости доллара и евро к рублю(можно добавить их 1-е разности)

# %%
first_diff = np.array(brent_data.iloc[1:,0].values - brent_data.iloc[:-1,0].values).astype('float32') 
brent_data['diff1'] = 0.0
brent_data['diff1'] =  brent_data['diff1'].astype('float') 
brent_data['diff1'].values[1:] = first_diff

# %%
rub_doll=pd.read_excel('RC_F01_01_2010_T31_12_2019.xlsx')
rub_doll.index = pd.to_datetime(rub_doll['data'].values).date
rub_doll.drop(['nominal','cdx','data'], axis=1,inplace = True)
rub_doll.columns = ['rub_doll_curs']
rub_doll['Date'] = rub_doll.index
rub_doll['Date'] =  rub_doll['Date'].astype('datetime64')
rub_doll.head()
# Out:
#             rub_doll_curs       Date
# 2010-01-01        30.1851 2010-01-01
# 2010-01-12        29.4283 2010-01-12
# 2010-01-13        29.3774 2010-01-13
# 2010-01-14        29.6409 2010-01-14
# 2010-01-15        29.4299 2010-01-15

# %%
rub_e=pd.read_excel('R_E01_01_2010_T31_12_2019.xlsx')
rub_e.index = pd.to_datetime(rub_e['data'].values).date
rub_e.drop(['nominal','cdx','data'], axis=1,inplace = True)
rub_e.columns = ['rub_euro_curs']
rub_e['Date'] = rub_e.index
rub_e['Date'] =  rub_e['Date'].astype('datetime64')
rub_e.head()
# Out:
#             rub_euro_curs       Date
# 2010-01-01        43.4605 2010-01-01
# 2010-01-12        42.6681 2010-01-12
# 2010-01-13        42.6149 2010-01-13
# 2010-01-14        42.9497 2010-01-14
# 2010-01-15        42.7764 2010-01-15

# %%
brent_data['Date'] = brent_data.index
brent_data['Date'] =  brent_data['Date'].astype('datetime64')
brent_data.shape
# Out:
# (2667, 13)

# %%
brent_data_curs = pd.merge(brent_data, rub_doll, on='Date', how='left')
brent_data_curses = pd.merge(brent_data_curs, rub_e, on='Date', how='left')
brent_data_curses = brent_data_curses.fillna(method='ffill')
brent_data_curses.head()
# Out:
#    Значение  year  month  dayofmonth  quarter  dayofyear  weekofyear  \
# 0     76.37  2010      9           1        3        244          35
# 1     76.89  2010      9           2        3        245          35
# 2     76.57  2010      9           3        3        246          35
# 3     76.62  2010      9           4        3        247          35
# 4     76.63  2010      9           5        3        248          35
#
#    dayofweek  is_holiday  is_prev_holiday  is_next_holiday  diff1       Date  \
# 0          2           0                0                0   0.00 2010-09-01
# 1          3           0                0                0   0.52 2010-09-02
# 2          4           0                0                0  -0.32 2010-09-03
# 3          5           0                0                0   0.05 2010-09-04
# 4          6           0                1                0   0.01 2010-09-05
#
#    rub_doll_curs  rub_euro_curs
# 0        30.8669        39.0127
# 1        30.8001        39.1654
# 2        30.6858        39.2901
# 3        30.6922        39.3505
# 4        30.6922        39.3505

# %%
first_diff_doll = np.array(brent_data_curses['rub_doll_curs'].values[1:] - brent_data_curses['rub_doll_curs'].values[:-1]).astype('float32') 
brent_data_curses['doll_diff1'] = 0.0
brent_data_curses['doll_diff1'] =  brent_data_curses['doll_diff1'].astype('float') 
brent_data_curses['doll_diff1'].values[1:] = first_diff_doll

# %%
first_diff_euro = np.array(brent_data_curses['rub_euro_curs'].values[1:] - brent_data_curses['rub_euro_curs'].values[:-1]).astype('float32') 
brent_data_curses['euro_diff1'] = 0.0
brent_data_curses['euro_diff1'] =  brent_data_curses['euro_diff1'].astype('float') 
brent_data_curses['euro_diff1'].values[1:] = first_diff_euro

# %%
brent_data_curses = brent_data_curses.set_index(['Date'])
brent_data_curses.head()
# Out:
#             Значение  year  month  dayofmonth  quarter  dayofyear  weekofyear  \
# Date
# 2010-09-01     76.37  2010      9           1        3        244          35
# 2010-09-02     76.89  2010      9           2        3        245          35
# 2010-09-03     76.57  2010      9           3        3        246          35
# 2010-09-04     76.62  2010      9           4        3        247          35
# 2010-09-05     76.63  2010      9           5        3        248          35
#
#             dayofweek  is_holiday  is_prev_holiday  is_next_holiday  diff1  \
# Date
# 2010-09-01          2           0                0                0   0.00
# 2010-09-02          3           0                0                0   0.52
# 2010-09-03          4           0                0                0  -0.32
# 2010-09-04          5           0                0                0   0.05
# 2010-09-05          6           0                1                0   0.01
#
#             rub_doll_curs  rub_euro_curs  doll_diff1  euro_diff1
# Date
# 2010-09-01        30.8669        39.0127      0.0000      0.0000
# 2010-09-02        30.8001        39.1654     -0.0668      0.1527
# 2010-09-03        30.6858        39.2901     -0.1143      0.1247
# 2010-09-04        30.6922        39.3505      0.0064      0.0604
# 2010-09-05        30.6922        39.3505      0.0000      0.0000

# %% [markdown]
#  3. сделайте ее перрасчет (ресемплинг) в представление по неделям.

# %%
w_brent_data=brent_data_curses.resample('W').mean()
w_brent_data.head()
# Out:
#              Значение    year     month  dayofmonth   quarter   dayofyear  \
# Date
# 2010-09-05  76.616000  2010.0  9.000000    3.000000  3.000000  246.000000
# 2010-09-12  77.673333  2010.0  9.000000    8.500000  3.000000  251.500000
# 2010-09-19  78.693333  2010.0  9.000000   15.666667  3.000000  258.666667
# 2010-09-26  78.518333  2010.0  9.000000   22.666667  3.000000  265.666667
# 2010-10-03  81.211667  2010.0  9.333333   19.666667  3.333333  272.666667
#
#             weekofyear  dayofweek  is_holiday  is_prev_holiday  \
# Date
# 2010-09-05        35.0   4.000000    0.000000              0.2
# 2010-09-12        36.0   2.500000    0.166667              0.0
# 2010-09-19        37.0   2.666667    0.000000              0.0
# 2010-09-26        38.0   2.666667    0.000000              0.0
# 2010-10-03        39.0   2.666667    0.000000              0.0
#
#             is_next_holiday     diff1  rub_doll_curs  rub_euro_curs  \
# Date
# 2010-09-05         0.000000  0.052000      30.747440      39.233840
# 2010-09-12         0.166667  0.288333      30.777050      39.302883
# 2010-09-19         0.000000 -0.021667      30.844500      39.764250
# 2010-09-26         0.000000  0.118333      31.012233      40.967983
# 2010-10-03         0.000000  0.791667      30.607417      41.345817
#
#             doll_diff1  euro_diff1
# Date
# 2010-09-05   -0.034940    0.067560
# 2010-09-12    0.033583   -0.026467
# 2010-09-19    0.021433    0.187483
# 2010-09-26   -0.003200    0.203567
# 2010-10-03   -0.081750   -0.016467

# %%
w_brent_data.drop(['dayofmonth', 'dayofyear', 'dayofweek'], axis=1,inplace=True)
w_brent_data['2011-10-01' : '2011-10-31']
# Out:
#               Значение    year      month   quarter  weekofyear  is_holiday  \
# Date
# 2011-10-02  103.878333  2011.0   9.166667  3.166667        39.0         0.0
# 2011-10-09  103.476667  2011.0  10.000000  4.000000        40.0         0.0
# 2011-10-16         NaN     NaN        NaN       NaN         NaN         NaN
# 2011-10-23  109.756667  2011.0  10.000000  4.000000        42.0         0.0
# 2011-10-30  110.680000  2011.0  10.000000  4.000000        43.0         0.0
#
#             is_prev_holiday  is_next_holiday     diff1  rub_doll_curs  \
# Date
# 2011-10-02         0.000000              0.0 -0.481667      32.026800
# 2011-10-09         0.166667              0.0  0.455000      32.466400
# 2011-10-16              NaN              NaN       NaN            NaN
# 2011-10-23         0.000000              0.0  1.806667      31.227767
# 2011-10-30         0.000000              0.0  0.050000      30.626467
#
#             rub_euro_curs  doll_diff1  euro_diff1
# Date
# 2011-10-02      43.391450   -0.005917    0.025967
# 2011-10-09      43.367483    0.105567   -0.004183
# 2011-10-16            NaN         NaN         NaN
# 2011-10-23      42.893333   -0.376567   -0.129000
# 2011-10-30      42.593517   -0.189450   -0.104783

# %%
w_brent_data.loc['2011-10-16'] = (w_brent_data.loc['2011-10-09'] + w_brent_data.loc['2011-10-23'])/2

# %%
np.isnan(w_brent_data).sum()
# Out:
# Значение           0
# year               0
# month              0
# quarter            0
# weekofyear         0
# is_holiday         0
# is_prev_holiday    0
# is_next_holiday    0
# diff1              0
# rub_doll_curs      0
# rub_euro_curs      0
# doll_diff1         0
# euro_diff1         0
# dtype: int64

# %%
# возьмем выборку чуть меньше, чтобы исключить баг
w_brent_data_ = w_brent_data[75:]

# %% [markdown]
#  4. Постройте модель предсказания 1-й точки от текущей (h=1).

# %% [markdown]
# По анализу признаков лучшие: ['Значение', 'year', 'is_prev_holiday', 'rub_doll_curs', 'rub_euro_curs'].
# Однако, поскольку нас интересует влияние дополнительного признака, построим модель на всех признаках.

# %%
# Горизонт прогнозирования h = 1, тогда target = y(t+h)=y(t+1)
from sklearn.preprocessing import StandardScaler

scl_target=StandardScaler() 
p = 14
h=1
target = w_brent_data_['Значение'].values[h+p:].reshape((w_brent_data_.shape[0]-h-p,1))
y = scl_target.fit_transform(target)
y.shape
# Out:
# (380, 1)

# %%
scl_x=StandardScaler() 

X = w_brent_data_.iloc[p:-h,:].values
X = scl_x.fit_transform(X.astype('float64'))
X.shape
# Размеры выборок по строкам совпали. Мы взяли на h строк меньше для Х и на h значений позднее по target. 
# Таким образом, входной набор данных сформирован.
# Out:
# (380, 13)

# %%
# Построим предсказание на всех признаках
from sklearn.ensemble import GradientBoostingRegressor

# %%
# сделаем функцию разбиения
def split_data( data, split_date ):
    return data.loc[data.index.get_level_values('Date') <= split_date].copy(), \
           data.loc[data.index.get_level_values('Date') >  split_date].copy()

# %%
train, test = split_data(w_brent_data_, '06-06-2018')

plt.figure( figsize=( 15, 7 ))
plt.xlabel('Время')
plt.ylabel('Цена нефти Brent')
plt.plot(train.index.get_level_values('Date'),train['Значение'], label='train data' )
plt.plot(test.index.get_level_values('Date'),test['Значение'], label='test data')
plt.title( 'Тестовые и тренировочные данные' )
plt.legend()
plt.show()

# %%
model_g = GradientBoostingRegressor(max_depth=5, random_state=0, n_estimators=100)

# %%
X_train = X[:train.shape[0],:]
y_train = y[:train.shape[0],0]
X_test = X[train.shape[0]:,:]
y_test = y[train.shape[0]:,0]

model_g.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, random_state=0)

# %%
y_test_pred_g = model_g.predict(X_test)

plt.figure( figsize=( 15, 7 ))


plt.xlabel('Время')
plt.ylabel('Цена нефти Brent')
plt.plot(test.index[h+p:],y_test_pred_g, label='predict GB data' )
plt.plot(test.index[h+p:],y_test, label='test data')

plt.legend()
plt.show()

# %%
#Оценим промах модели, используя метрики
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
er_s = mean_squared_error(y_true=y_test, y_pred=y_test_pred_g) 
er_a = mean_absolute_error(y_true=y_test, y_pred=y_test_pred_g) 
er_r2 = r2_score(y_true=y_test, y_pred=y_test_pred_g)

print('ошибка mse :  ', er_s,'\nошибка mae  :  ', er_a,'\nоценка R2 :  ', er_r2)
# Out:
# ошибка mse :   0.011541081883998043
# ошибка mae  :   0.08673518716836229
# оценка R2 :   0.8563039660481694

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
er_g = mean_absolute_percentage_error(y_true=scl_target.inverse_transform( y_test),y_pred = scl_target.inverse_transform(y_test_pred_g))

print('ошибка градиентного бустинга MAPE :  ', er_g,'%')
# Out:
# ошибка градиентного бустинга MAPE :   3.3098231624898515 %

# %%
#Воспользуемся методом поиска
from sklearn.model_selection import RandomizedSearchCV

def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

param_dist = {"max_depth": [2, 3, 4, 5, 6, 7, 8, 9, 10, 12, 15], 
              "n_estimators":[100, 200, 300, 400, 500, 1000, 1200, 1500, 2000, 3000]}

#  randomized search
n_iter_search = 100

model_gr = GradientBoostingRegressor()

random_search = RandomizedSearchCV(model_gr, param_distributions=param_dist, n_iter=n_iter_search, cv=5, iid=False)

random_search.fit(X_train, y_train)

report(random_search.cv_results_)
# Out:
# Model with rank: 1
# Mean validation score: 0.795 (std: 0.066)
# Parameters: {'n_estimators': 1000, 'max_depth': 2}
#
# Model with rank: 2
# Mean validation score: 0.781 (std: 0.100)
# Parameters: {'n_estimators': 3000, 'max_depth': 2}
#
# Model with rank: 3
# Mean validation score: 0.778 (std: 0.090)
# Parameters: {'n_estimators': 1200, 'max_depth': 2}

# %%
# Выбираем модель с рангом 1 и проведем ее обучение на тренировочном наборе
model_g_best = GradientBoostingRegressor(max_depth=2, n_estimators=1000)
model_g_best.fit( X_train, y_train ) 
y_test_pred_g = model_g_best.predict(X_test)

er_s = mean_squared_error(y_true=y_test, y_pred=y_test_pred_g) 
er_a = mean_absolute_error(y_true=y_test, y_pred=y_test_pred_g) 
er_r2 = r2_score(y_true=y_test, y_pred=y_test_pred_g)
print('ошибка mse :  ', er_s,'\nошибка mae  :  ', er_a,'\nоценка R2 :  ', er_r2)

er_g = mean_absolute_percentage_error(y_true=scl_target.inverse_transform( y_test),y_pred = scl_target.inverse_transform( y_test_pred_g))
print('ошибка градиентного бустинга MAPE :  ', er_g,'%')
# Out:
# ошибка mse :   0.008990963589419684
# ошибка mae  :   0.080936854001212
# оценка R2 :   0.8880550521874155
# ошибка градиентного бустинга MAPE :   3.0606425583382153 %

# %% [markdown]
# Показатели улучшились.

# %% [markdown]
#  5. Добавьте еще один экзогенный фактор - любой:)
#
#  Доу-Джонс | Золото: https://investfunds.ru/indexes/221/

# %%
dow_jones=pd.read_excel('dow-jones.xlsx')
dow_jones.columns = ['Date', 'dow_jones']
dow_jones['Date'] =  dow_jones['Date'].astype('datetime64[ns]')
brent_data_curses_dj = pd.merge(brent_data_curses, dow_jones, on='Date', how='left')
brent_data_curses_dj.head()
# Out:
#         Date  Значение  year  month  dayofmonth  quarter  dayofyear  \
# 0 2010-09-01     76.37  2010      9           1        3        244
# 1 2010-09-02     76.89  2010      9           2        3        245
# 2 2010-09-03     76.57  2010      9           3        3        246
# 3 2010-09-04     76.62  2010      9           4        3        247
# 4 2010-09-05     76.63  2010      9           5        3        248
#
#    weekofyear  dayofweek  is_holiday  is_prev_holiday  is_next_holiday  diff1  \
# 0          35          2           0                0                0   0.00
# 1          35          3           0                0                0   0.52
# 2          35          4           0                0                0  -0.32
# 3          35          5           0                0                0   0.05
# 4          35          6           0                1                0   0.01
#
#    rub_doll_curs  rub_euro_curs  doll_diff1  euro_diff1  dow_jones
# 0        30.8669        39.0127      0.0000      0.0000   10269.47
# 1        30.8001        39.1654     -0.0668      0.1527   10320.10
# 2        30.6858        39.2901     -0.1143      0.1247   10447.93
# 3        30.6922        39.3505      0.0064      0.0604        NaN
# 4        30.6922        39.3505      0.0000      0.0000        NaN

# %%
dfaur=pd.read_excel('aur.xlsx')
dfaur.columns = ['Date', 'val_aur']
dfaur['Date'] =  dfaur['Date'].astype('datetime64[ns]')
brent_data_curses_aur = pd.merge(brent_data_curses, dfaur, on='Date', how='left')
brent_data_curses_aur.head()
# Out:
#         Date  Значение  year  month  dayofmonth  quarter  dayofyear  \
# 0 2010-09-01     76.37  2010      9           1        3        244
# 1 2010-09-02     76.89  2010      9           2        3        245
# 2 2010-09-03     76.57  2010      9           3        3        246
# 3 2010-09-04     76.62  2010      9           4        3        247
# 4 2010-09-05     76.63  2010      9           5        3        248
#
#    weekofyear  dayofweek  is_holiday  is_prev_holiday  is_next_holiday  diff1  \
# 0          35          2           0                0                0   0.00
# 1          35          3           0                0                0   0.52
# 2          35          4           0                0                0  -0.32
# 3          35          5           0                0                0   0.05
# 4          35          6           0                1                0   0.01
#
#    rub_doll_curs  rub_euro_curs  doll_diff1  euro_diff1  val_aur
# 0        30.8669        39.0127      0.0000      0.0000  1224.12
# 1        30.8001        39.1654     -0.0668      0.1527  1237.81
# 2        30.6858        39.2901     -0.1143      0.1247  1230.99
# 3        30.6922        39.3505      0.0064      0.0604  1235.44
# 4        30.6922        39.3505      0.0000      0.0000      NaN

# %%
brent_data_curses_dj = brent_data_curses_dj.set_index(['Date'])
brent_data_curses_dj = brent_data_curses_dj.fillna(method='ffill')
w_brent_data2=brent_data_curses_dj.resample('W').mean()
w_brent_data2.drop(['dayofmonth', 'dayofyear', 'dayofweek'], axis=1,inplace=True)
w_brent_data2.loc['2011-10-16'] = (w_brent_data2.loc['2011-10-09'] + w_brent_data2.loc['2011-10-23'])/2

# %%
brent_data_curses_aur = brent_data_curses_aur.set_index(['Date'])
brent_data_curses_aur = brent_data_curses_aur.fillna(method='ffill')
w_brent_data3=brent_data_curses_aur.resample('W').mean()
w_brent_data3.drop(['dayofmonth', 'dayofyear', 'dayofweek'], axis=1,inplace=True)
w_brent_data3.loc['2011-10-16'] = (w_brent_data3.loc['2011-10-09'] + w_brent_data3.loc['2011-10-23'])/2

# %%
# возьмем выборку чуть меньше
w_brent_data_2 = w_brent_data2[75:]
w_brent_data_2.head()
# Out:
#               Значение    year  month  quarter  weekofyear  is_holiday  \
# Date
# 2012-02-12  117.163333  2012.0    2.0      1.0         6.0    0.000000
# 2012-02-19  119.078333  2012.0    2.0      1.0         7.0    0.000000
# 2012-02-26  123.106667  2012.0    2.0      1.0         8.0    0.166667
# 2012-03-04  123.461667  2012.0    2.5      1.0         9.0    0.000000
# 2012-03-11  124.413333  2012.0    3.0      1.0        10.0    0.000000
#
#             is_prev_holiday  is_next_holiday     diff1  rub_doll_curs  \
# Date
# 2012-02-12         0.000000         0.000000  0.415000      29.926167
# 2012-02-19         0.166667         0.000000  0.556667      30.002867
# 2012-02-26         0.000000         0.166667  0.756667      29.846250
# 2012-03-04         0.000000         0.000000 -0.288333      29.241500
# 2012-03-11         0.000000         0.000000  0.251667      29.502533
#
#             rub_euro_curs  doll_diff1  euro_diff1     dow_jones
# Date
# 2012-02-12      39.517367   -0.084333   -0.048283  12850.033333
# 2012-02-19      39.452817    0.088383   -0.026433  12889.515000
# 2012-02-26      39.401150   -0.073433    0.015550  12967.470000
# 2012-03-04      39.120150   -0.080050   -0.056667  12979.023333
# 2012-03-11      38.929650    0.062200   -0.012933  12885.211667

# %%
# возьмем выборку чуть меньше
w_brent_data_3 = w_brent_data3[75:]
w_brent_data_3.head()
# Out:
#               Значение    year  month  quarter  weekofyear  is_holiday  \
# Date
# 2012-02-12  117.163333  2012.0    2.0      1.0         6.0    0.000000
# 2012-02-19  119.078333  2012.0    2.0      1.0         7.0    0.000000
# 2012-02-26  123.106667  2012.0    2.0      1.0         8.0    0.166667
# 2012-03-04  123.461667  2012.0    2.5      1.0         9.0    0.000000
# 2012-03-11  124.413333  2012.0    3.0      1.0        10.0    0.000000
#
#             is_prev_holiday  is_next_holiday     diff1  rub_doll_curs  \
# Date
# 2012-02-12         0.000000         0.000000  0.415000      29.926167
# 2012-02-19         0.166667         0.000000  0.556667      30.002867
# 2012-02-26         0.000000         0.166667  0.756667      29.846250
# 2012-03-04         0.000000         0.000000 -0.288333      29.241500
# 2012-03-11         0.000000         0.000000  0.251667      29.502533
#
#             rub_euro_curs  doll_diff1  euro_diff1      val_aur
# Date
# 2012-02-12      39.517367   -0.084333   -0.048283  1666.650000
# 2012-02-19      39.452817    0.088383   -0.026433  1662.071667
# 2012-02-26      39.401150   -0.073433    0.015550  1670.685000
# 2012-03-04      39.120150   -0.080050   -0.056667  1648.983333
# 2012-03-11      38.929650    0.062200   -0.012933  1604.846667

# %% [markdown]
#  6. Сравните модель с дополнительным экзогенным фактором и исходную и сделайте вывод о поведении ошибки предсказания ряда в сравнении с прямым прогнозированием.

# %%
train2, test2 = split_data(w_brent_data_2, '06-06-2018')

# Горизонт прогнозирования h = 1, тогда target = y(t+h)=y(t+1)
p = 14
h=1
target2 = w_brent_data_2['Значение'].values[h+p:].reshape((w_brent_data_2.shape[0]-h-p,1))
y2 = scl_target.fit_transform(target2)
y2.shape
# Out:
# (380, 1)

# %%
X2 = w_brent_data_2.iloc[p:-h,:].values
X2 = scl_x.fit_transform(X2.astype('float64'))
X2.shape
# Out:
# (380, 14)

# %%
X_train2 = X2[:train2.shape[0],:]
y_train2 = y2[:train2.shape[0],0]
X_test2 = X2[train2.shape[0]:,:]
y_test2 = y2[train2.shape[0]:,0]

model_g_best.fit(X_train2, y_train2)
# Out:
# GradientBoostingRegressor(max_depth=2, n_estimators=1200)

# %%
y_test_pred_g2 = model_g_best.predict(X_test2)

plt.figure( figsize=( 15, 7 ))


plt.xlabel('Время')
plt.ylabel('Цена нефти Brent')
plt.plot(test2.index[h+p:],y_test_pred_g2, label='predict GB data' )
plt.plot(test2.index[h+p:],y_test2, label='test data')

plt.legend()
plt.show()

# %%
er_s = mean_squared_error(y_true=y_test2, y_pred=y_test_pred_g2) 
er_a = mean_absolute_error(y_true=y_test2, y_pred=y_test_pred_g2) 
er_r2 = r2_score(y_true=y_test2, y_pred=y_test_pred_g2)

print('ошибка mse :  ', er_s,'\nошибка mae  :  ', er_a,'\nоценка R2 :  ', er_r2)
# Out:
# ошибка mse :   0.010570090726015993
# ошибка mae  :   0.08844315993388854
# оценка R2 :   0.8683936106591978

# %%
er_g = mean_absolute_percentage_error(y_true=scl_target.inverse_transform(y_test2),y_pred = scl_target.inverse_transform(y_test_pred_g2))

print('ошибка градиентного бустинга MAPE :  ', er_g,'%')
# Out:
# ошибка градиентного бустинга MAPE :   3.3540332598057963 %

# %% [markdown]
# Видим, что все оценочные показатели немного хуже по сравнению с теми, что были до добавления дополнительного параметра.

# %% [markdown]
# __+ золото только из любопытства__

# %%
train2, test2 = split_data(w_brent_data_3, '06-06-2018')

# Горизонт прогнозирования h = 1, тогда target = y(t+h)=y(t+1)
p = 14
h=1
target2 = w_brent_data_2['Значение'].values[h+p:].reshape((w_brent_data_2.shape[0]-h-p,1))
y2 = scl_target.fit_transform(target2)
y2.shape
# Out:
# (380, 1)

# %%
X2 = w_brent_data_3.iloc[p:-h,:].values
X2 = scl_x.fit_transform(X2.astype('float64'))
X2.shape
# Out:
# (380, 14)

# %%
X_train2 = X2[:train2.shape[0],:]
y_train2 = y2[:train2.shape[0],0]
X_test2 = X2[train2.shape[0]:,:]
y_test2 = y2[train2.shape[0]:,0]

model_g_best.fit(X_train2, y_train2)
# Out:
# GradientBoostingRegressor(max_depth=2, n_estimators=1000)

# %%
y_test_pred_g2 = model_g_best.predict(X_test2)

plt.figure( figsize=( 15, 7 ))


plt.xlabel('Время')
plt.ylabel('Цена нефти Brent')
plt.plot(test2.index[h+p:],y_test_pred_g2, label='predict GB data' )
plt.plot(test2.index[h+p:],y_test2, label='test data')

plt.legend()
plt.show()

# %%
er_s = mean_squared_error(y_true=y_test2, y_pred=y_test_pred_g2) 
er_a = mean_absolute_error(y_true=y_test2, y_pred=y_test_pred_g2) 
er_r2 = r2_score(y_true=y_test2, y_pred=y_test_pred_g2)

print('ошибка mse :  ', er_s,'\nошибка mae  :  ', er_a,'\nоценка R2 :  ', er_r2)
# Out:
# ошибка mse :   0.009277718913145001
# ошибка mae  :   0.08240746954483955
# оценка R2 :   0.8844847107629228

# %%
er_g = mean_absolute_percentage_error(y_true=scl_target.inverse_transform(y_test2),y_pred = scl_target.inverse_transform(y_test_pred_g2))

print('ошибка градиентного бустинга MAPE :  ', er_g,'%')
# Out:
# ошибка градиентного бустинга MAPE :   3.140942031165129 %

# %% [markdown]
# с золотом вышло чуть лучше, но без экзогенных факторов выходит лучше (
